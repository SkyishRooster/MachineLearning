# %% [markdown]
# ### 1. Using 04_hotel_cancellation.csv, estimate the treatment effects if a ‘different room is assigned’ as the treatment indicator and interpret its effect on the room being ‘canceled’. Treat all the other columns as the covariates.

# %%
#!pip install causalinference
#!pip install python-dotenv
#!conda install -c r r-glmnet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import math

from causalinference import CausalModel

# %%
# Overview of the dataset
hotel = pd.read_csv("04_hotel_cancellation.csv")
hotel.head()
# Out:
#    Unnamed: 0  lead_time  arrival_date_year  arrival_date_week_number  \
# 0           3         13               2015                        27
# 1           4         14               2015                        27
# 2           5         14               2015                        27
# 3           7          9               2015                        27
# 4           8         85               2015                        27
#
#    arrival_date_day_of_month  days_in_waiting_list  different_room_assigned  \
# 0                          1                     0                    False
# 1                          1                     0                    False
# 2                          1                     0                    False
# 3                          1                     0                    False
# 4                          1                     0                    False
#
#    is_canceled
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True

# %%
# Create the treatment indicator
d = hotel[['different_room_assigned']]
d = d.replace({True:1, False:0})

# Create the observed outcome
y = hotel[['is_canceled']]
y = y.replace({True:1, False:0})

# Create the covariates matrix
X = hotel.iloc[:,1:6]

# %%
# Create the causal model
causal = CausalModel(D = d.values, Y = y.values, X = X.values)
print(causal.summary_stats)
# Out:
# Summary Statistics
#
#                      Controls (N_c=91673)       Treated (N_t=11221)
#        Variable         Mean         S.d.         Mean         S.d.     Raw-diff
# --------------------------------------------------------------------------------
#               Y        0.432        0.495        0.051        0.220       -0.381
#
#                      Controls (N_c=91673)       Treated (N_t=11221)
#        Variable         Mean         S.d.         Mean         S.d.     Nor-diff
# --------------------------------------------------------------------------------
#              X0      116.468      109.178       73.114       85.262       -0.443
#              X1     2016.182        0.703     2015.949        0.695       -0.334
#              X2       27.249       13.100       28.076       14.651        0.060
#              X3       15.804        8.804       15.642        8.714       -0.019
#              X4        2.644       18.955        2.422       17.457       -0.012

# %%
# includes the treatment variable and the covariates as the model predictors
causal.est_via_ols(adj=1)
print('adj=1', causal.estimates)
# Out:
# adj=1
# Treatment Effect Estimates: OLS
#
#                      Est.       S.e.          z      P>|z|      [95% Conf. int.]
# --------------------------------------------------------------------------------
#            ATE     -0.337      0.003   -118.276      0.000     -0.343     -0.332
# C:\Users\59699\anaconda3\lib\site-packages\causalinference\estimators\ols.py:21: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   olscoef = np.linalg.lstsq(Z, Y)[0]

# %% [markdown]
# Observations:
# 1. The estimated average treatment effect is -0.337
# 2. The p-value of the estimation is extremely small and the 95% confidence interval doesn't include zero, we can conclude that the whether be assigned a different room or not affects the likelihood for a customer to cancel a room
# 3. The negative estimated average treatment effect indicates that when a different room is assigned to a customer, the chance of the customer to cancel the reservation is estimated to reduce, controlling other covariates.

# %%
# Use logit model to estimate the treatment effect
x = pd.concat([X,d], axis = 1)

model = sm.Logit(y,x)
result = model.fit()
print(result.params)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.598443
#          Iterations 7
# lead_time                    0.005202
# arrival_date_year           -0.000375
# arrival_date_week_number    -0.004168
# arrival_date_day_of_month   -0.001143
# days_in_waiting_list         0.001325
# different_room_assigned     -2.518556
# dtype: float64

# %% [markdown]
# Observations:<br>
# Logit model also gives a negative treatment effect: -2.52. It validated the result we got from the causal model that assigning a different room to a customer leads to lower chance of cancel the book, controling other covariates.

# %%
'''
Notes for CausalModel:
# only includes the treatment variable as the model predictors
causal.est_via_ols(adj=0)
print('adj=0', causal.estimates)

# includes the treatment variable, the covariates, and the interactions between the treatment variable and the covariates as model predictors
causal.est_via_ols(adj=2)
print('adj=2', causal.estimates)
'''
# Out:
# "\nNotes for CausalModel:\n# only includes the treatment variable as the model predictors\ncausal.est_via_ols(adj=0)\nprint('adj=0', causal.estimates)\n\n# includes the treatment variable, the covariates, and the interactions between the treatment variable and the covariates as model predictors\ncausal.est_via_ols(adj=2)\nprint('adj=2', causal.estimates)\n"

# %% [markdown]
# ### 2. For 04_hotel_cancellation.csv, use double lasso regression to measure the effect of ‘different room is assigned’ on the room being ‘canceled’

# %%
# Estimate d_hat
logit_1 = sm.Logit(d, X).fit()
d_hat = logit_1.predict(X)

# Combine d_hat and the rest variables
d_hat = pd.DataFrame(data = {"d_hat": d_hat[:]})
x_new = pd.concat([x,d_hat], axis = 1)

# The second stage logistic regression
logit_2 = sm.Logit(y, x_new).fit()
print(logit_2.params)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.334283
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.596827
#          Iterations 7
# lead_time                     0.000658
# arrival_date_year             0.000395
# arrival_date_week_number      0.005383
# arrival_date_day_of_month    -0.004647
# days_in_waiting_list          0.004968
# different_room_assigned      -2.504256
# d_hat                       -11.692611
# dtype: float64

# %% [markdown]
# ### 3. Use bootstrap to estimate the standard error of the treatment effects measured in (2).

# %%
# Define the number of resampling
n = 1000

# Initialize the vector to store the treatment effects
treatment_effects = np.zeros(1000)

# Bootstrap the original dataset and collect treatment effects
i = 0
while i < n:
    resample_index = np.random.choice(hotel.index, size = hotel.index.size, replace = True)
    resample = hotel.iloc[resample_index]
    X_resample = X.iloc[resample_index]
    x_resample = x.iloc[resample_index]
    y_resample = y.iloc[resample_index]
    
    model1 = sm.Logit(y_resample, X_resample).fit()
    d_hat = np.array(model1.predict(X_resample)).reshape(X_resample.shape[0],1)
    x_new = np.hstack((x_resample,d_hat))
    
    model2 = sm.Logit(y_resample, x_new).fit()
    
    treatment_effects[i] = model2.params[-2]
    
    i += 1
# Out:
# Optimization terminated successfully.
#          Current function value: 0.628765
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596911
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629470
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597290
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630679
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598874
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629691
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597741
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629883
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598253
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629874
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596954
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628641
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596447
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629683
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597671
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.627787
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595733
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.627479
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596050
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629369
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596562
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628387
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596920
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629444
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597271
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628256
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595564
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.631693
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.599545
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629673
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597688
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630066
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598299
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628515
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597705
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629920
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598187
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628577
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596223
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630243
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597885
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.627416
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594809
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629493
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598015
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630458
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599088
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628990
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597464
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.632461
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.599173
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630692
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.599805
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628531
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595342
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629002
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.596765
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630084
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597228
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628818
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.596208
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630193
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597631
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629580
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597291
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630993
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597934
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630407
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598049
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629751
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597247
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629703
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597443
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.631794
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598344
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629948
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597784
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629141
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597459
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629628
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597562
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629603
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597036
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629463
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597472
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630267
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598199
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628657
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596541
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630055
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597860
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630614
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597591
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628284
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596329
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629287
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596867
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628363
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596351
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629335
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599040
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629523
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.595297
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629748
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597851
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.631332
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.600373
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628709
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595187
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628180
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596913
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630967
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.599147
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628991
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597094
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629462
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596716
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630298
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599436
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629484
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.596893
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629074
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597751
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630628
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598483
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630061
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598199
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630032
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597864
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629260
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597390
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629340
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597331
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.627069
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595227
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628924
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.596937
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630599
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.599096
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629429
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596360
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628344
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.596039
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630701
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596878
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628806
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597864
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629233
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596510
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629426
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598969
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630448
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597775
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.631595
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598771
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629646
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598355
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628053
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594858
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629872
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.596767
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.627438
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594794
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629933
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597906
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628369
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596808
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629033
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.596369
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630356
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598792
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629467
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597227
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629465
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597433
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629341
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598310
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629856
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597990
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628976
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596523
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628386
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.595349
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630516
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.599659
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629819
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598502
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.632164
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.599268
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628548
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597262
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629024
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597475
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630306
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.597103
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629951
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.596979
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.627916
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597474
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630792
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598532
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629458
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597319
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.627471
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595814
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629317
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597181
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.631490
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598658
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630025
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.599403
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629627
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597453
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.631540
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.600096
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629239
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597703
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.628182
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595320
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.630253
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.598890
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.629328
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.